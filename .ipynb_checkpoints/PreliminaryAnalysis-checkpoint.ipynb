# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pylab as plt
import re
import string
import difflib
import Levenshtein
# def findWholeWord(w):
#     return re.compile(r'\b({0})\b'.format(w), flags=re.IGNORECASE).search
# mid_st_dict = {}
# for id in missingIds:
#     mid_st_dict[id] = [sind for sind in st_mathced_Info.index if id in st_mathced_Info.ix[sind].All_majors.split(';')]
mst = ['masters','master','MA', 'MS', 'MEd', 'MSc', 'MEB', 'MDes', 'MNCM', 'MSN', \
       'MSW', 'MPA', 'MPC', 'MPP','MPH', 'MC', 'MCA', 'MCouns', 'MLA', 'MLIS', 'MDiv', \
       'ALM', 'MiM', 'MBA','emba','iMBA', 'MBA Tech', 'MCom', 'MBus', 'MI', 'PSM', \
       'MEng', 'MMath', 'MPhys', 'MPsych', 'MSci', 'MChem', 'MBiol', 'MGeol',\
       'dpm','dmd','doctor','phd','ph d','dphi','doctorate','post-doc']
ID = {'6030500':'Advertising Graphic Design','8020310':'Elementary Education','19140000':'Geology',\
      '21030020':'Tourism','3050001':'Africa America Study','5132100':'International Business','5131500':'Business',
      '5131700':'Business Law','6020000':'Journalism','12680010':'HealthInfo Management','17010000':'Math',\
      '5000105':'Business Management','22010100':'Women Study','21030030':'Sports RecreationManage','5000104':'Business Management',\
      '19808000':'Environmental Study','6060000':'Mass Media','5131300':'Finance','22040300':'Economics',\
      '15090000':'Philosophy','8030700':'Secondary Education','54020500':'Community Reginal Relation',\
      '7010100':'Magage Info System','7020000':'Computer Science','7020100':'Info Science and Tech',\
      '12030000':'Registed Nurse','22140350':'Cartography','6090000':'Communication General',\
      '6080000':'Speech Communication','5110000':'Real Estate','9220100':'Environmental Engineering',\
      '5000100':'Business Administration'}
studentInfo = pd.read_csv('../studentInfo5.csv',sep='\t',dtype=object)
print studentInfo.shape
majorDict = pd.read_csv('../majordict.csv', sep=',',dtype='object')
majorDict.Name[pd.isnull(majorDict.Name)] = ''
majorDict.Name = [name.translate(string.maketrans("",""), string.punctuation) for name in majorDict.Name]
majorDict.loc[len(majorDict)] = ['','']
majorDict.index = majorDict.ID
# %pylab inline
manualMatchTable = pd.read_csv('../manualMatchedTable.csv',index_col=0,dtype=object)
studentNonGrad = studentInfo[~studentInfo.Graduated_or_not.astype('int').astype('bool')]
studentGrad = studentInfo[studentInfo.Graduated_or_not.astype('int').astype('bool')]
studentGrad.GradMj_Reported[pd.isnull(studentGrad.GradMj_Reported)] = ''
studentGrad.GradMjReName = [majorDict.ix[major].Name for major in studentGrad.GradMj_Reported.astype('object')]
manualGrad = manualMatchTable[manualMatchTable.Graduated_or_not.astype('int').astype('bool')]
manualGrad.GradMjReName = studentGrad.ix[manualGrad.Index_x.astype('int')].GradMjReName.values
# studentInfo['EntryMjName'] = majorDict.ix[studentInfo.Entry_Major.astype('S').values[:]].Name.values
# studentInfo['EndMjName'] = majorDict.ix[studentInfo.EndMj.astype('S').values[:]].Name.values
# studentInfo.Unique_Majors[pd.isnull(studentInfo.Unique_Majors)] = ''
# studentInfo.All_majors[pd.isnull(studentInfo.All_majors)] = ''
# studentInfo.GradMj_Extracted[pd.isnull(studentInfo.GradMj_Extracted)] = ''
# studentInfo.GradMj_Reported[pd.isnull(studentInfo.GradMj_Reported)] = ''
# studentInfo['UniqMajorName'] = [';'.join(majorDict.ix[major.split(';')].Name.values) \
#                                 for major in studentInfo.Unique_Majors.astype('S').values]
# studentInfo['AllMajorName'] = [';'.join(majorDict.ix[major.split(';')].Name.values) \
#                                 for major in studentInfo.All_majors.astype('S').values]
# studentInfo['GradMjExName'] = [majorDict.ix[major] for major in studentInfo.GradMj_Extracted.astype('S').values]
# studentInfo['GradMjReName'] = [majorDict.ix[major] for major in studentInfo.GradMj_Reported.astype('S').values]
# Out:
# (10978, 30)
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
################## Check the missing rate for linkedin data in our records ###############
# Merge the education table.
education = [ pd.read_csv('../part-%05d-education.csv' %i, sep='\t') for i in range(0,10)]
education = [edu[~pd.isnull(edu.FullName)] for edu in education]
for i, edu in enumerate(education):
    edu['File'] = np.zeros((len(edu),)) + i
education = pd.concat(education,axis=0)
education.FullName = education.FullName.str.title()
education.FirstName = education.FirstName.str.title()
education.LastName = education.LastName.str.title()
print len(education)
print len(education.groupby(['File','Index']))

# Preprocessing the names of Education Table
education.FullName = [name.split(',')[0] for name in education.FullName] ## Remove the afflication in the names
education.FullName = [name.translate(string.maketrans("",""), string.punctuation) for name in education.FullName]
education.FirstName = [' '.join(name.split()[:-1]) for name in education.FullName]
education.LastName = [name.split()[-1] for name in education.FullName]

# Remove the records that has no temple university background
education.University[pd.isnull(education.University)] = ''
reg = re.compile(r'(?i)\b(?:%s)\b' % ('temple'), re.IGNORECASE)
education = education[[bool(reg.search(uni)) for uni in  education.University.values]]
print len(education)

# Keep only students from 1997 - 2011
education = education[((education.StartYear.astype('float') >= 1997) \
                         & (education.StartYear.astype('float') <= 2011))]
print len(education)
# Remove whoever are master or doctorate
education.Degree[pd.isnull(education.Degree)] = ''
education.Major[pd.isnull(education.Major)] = ''
education.Major = [' '.join(major.translate(string.maketrans("",""),string.punctuation).split()) for major in education.Major]
education.Degree = [' '.join(degree.translate(string.maketrans("",""),string.punctuation).split()) for degree in education.Degree]
education.Major = education.Major.str.title()
education.Degree = education.Degree.str.title()
degrees = [''.join(x.split('.')) for x in education.Degree]
majors = [''.join(x.split('.')) for x in education.Major]
reg = re.compile(r'(?i)\b(?:%s)\b' % ('|'.join(mst)))
masterOrPhD = [bool(reg.search(stdg)) | bool(reg.search(stmj)) for (stdg,stmj) in zip(degrees,majors)]
education = education[~ np.array(masterOrPhD)]
print len(education)
# Out:
# 186720
# 87384
# 88829
# 36630
# 29073

# %%
uniqueMajorsLinkedIn = education.Major.value_counts()
uniqueMajorsLinkedIn[uniqueMajorsLinkedIn==1].index
# Out:
# Index([u'Health Care Management', u'Landscape Architecture Horticulture', u'Psychology And Literature', u'Entrepreneurial And Small Business Operations Marketing Minor', u'Political Science And International Relations', u'Jewish Studies And Political Science', u'Ee', u'Brand Management', u'Advertisingmarketing', u'Computer Applications', u'Geography And Urban Development Sociology', u'Diagnostic Medical Sonography', u'Summa Cum Laude', u'Journalism Public Relations And Advertising Anthropology', u'Taxation Estate Planning Certificate', u'Civil Engineering Concentration Environmental Engineering', u'Sociology Women Studies', u'Env Studies', u'Film Production Photography', u'Major Political Science Minor History', u'May 2013', u'Business Negotiation', u'Law Health Law', u'Tourism Hospitality Management Business', u'Advanced Constitutional Law Family Law Apellate Advocacy', u'Special And Elementary Education', u'Liberal And Visual Arts', u'Sport And Recreation Management Business Minor', u'Microsoft Access', u'Filmmedia Arts Philosophy', u'Sport And Recreation Managementbusiness Administration', u'Major Biology Minor Public Health', u'Graphic Design Art Education', u'Art History Leadership Minor', u'Sociologypolitical Science', u'Double Major Mis And Business Administration', u'Sport And Recreation Management Sport Management', u'Insurance Risk Management And International Business', u'Fed Tax', u'Marketing Management Information System', u'Tourism Hospitality Managment Business Minor', u'Majors Risk Management Insurance Finance', u'Broadcastingbusinessmarketing', u'International Business And Film', u'Advertising Marketing Graphic Design Copywriting', u'Sports Journalism', u'Adult And Organizational Development Concentration In Education', u'Mechanical Engineering With Concentration In Energy Systems', u'Communications Advertising Copywriting', u'Intellectual Property Business Law', u'Tokyo Study Abroad', u'Marketing Digital Media', u'Btmm Broadcasting Telecommunications Mass Media', u'Business Admnistration', u'Architecture Design', u'Stoc Public Relations Marketing And Advertising', u'Technical Education In Computer Technology And Web Design', u'Transformational Social Therapy', u'Sports And Recreation Management At Fox School Of Business', u'Advertising Italian Minor', u'Managing Information Systems Marketing', u'Advertising And Business Administration', u'Legal Assistantparalegal', u'Strategic Communication Rhetoric And Public Advocacy', u'Bachelors In Fine Arts Graphic Design', u'Communicationitalian', u'International And Intellectual Property Law', u'Programa De Ley Semestral', u'Neuroscience Premed Spanish', u'Major Legal Studies In Business Minor Management Information Systems', u'Finance Real Estate Entrepreneurship', u'Video Production Management', u'Biology Pre Dental', u'Communiction', u'Englishfilm Studies', u'Civil And Construction Engineering Business', u'Human Resource Management 2004', u'Human Resource Major', u'Film Amp Media Arts Business', u'American History United States Sociology', u'Strategical Communciations With A Concentration In Public Relations', u'Major Spanish Professional Studies Minor Anthropology', u'Double Major Nursing Psychology Minor History', u'Strategic Communication Geography And Urban Studies', u'Database Management And Design', u'Political Science Geography Urban Studies Gus', u'Systems', u'Hospitality Operations Spanish Minor', u'Tourism And Hospitality Management General Business Minor', u'Sociology Political Science', u'Clinical Trials Management', u'Bachelor Of Science In Bible', u'Broadcast Journalism And Meteorology', u'Architecturelandscape Architecture', u'Dance Performance', u'Music Performance General Voice Music Education', u'Communications Photojournalism', u'Japanese Elements I Asian Religions And Japanese Culture', u'Criminal Justice Minor Accounting', u'Magazine Journalism English Writing Certificate', ...], dtype='object')

# %%
keywords = ['chemistry']
keywordsnot = ['education','teaching']
mgm = [bool(re.compile(r'(?i)\b(?:%s)\b' % ('|'.join(keywords))).search(major)) & \
       (not bool(re.compile(r'(?i)\b(?:%s)\b' % ('|'.join(keywordsnot))).search(major)))\
                      for major in uniqueMajorsLinkedIn.index]
print uniqueMajorsLinkedIn[mgm]
sum(uniqueMajorsLinkedIn[mgm])
# Out:
# Chemistry                                                       158
# Organic Chemistry                                                 3
# Chemistry And Biochemistry                                        1
# Chemistry Major And Business Minor                                1
# Chemistry Wteaching                                               1
# Chemistry Religion                                                1
# Classics History Chemistry                                        1
# Biology Chemistry                                                 1
# Chemistry Ba Film And Media Arts                                  1
# Major In Chemistry Biology                                        1
# Biology Premedicine Chemistry Minor                               1
# Bio Chemistry                                                     1
# Chemistry General Science                                         1
# Chemistry With A Focus In Organic Synthesis                       1
# Organic Chemistry Graduate Classes                                1
# Analytical Chemistry French                                       1
# Chemistry Mathematics                                             1
# Chemistry 2004                                                    1
# Chemistry Chemistry                                               1
# Chemistry Biochemistry                                            1
# Organic Chemistry Synthetic Chemistry                             1
# Pharmacy Chemistry Biology                                        1
# Biology And Chemistry                                             1
# Natural Sciences With A Focus In Chemistry                        1
# Geologymajor Biologyminor Geographyminor Coastal Geomorphology Chemistry      1
# Chemistry Computer Science                                        1
# Economics Chemistry                                               1
# Chemistry Geology Minor                                           1
# Chemistry Business Womens Studies                                 1
# Graduate Studies In Chemistry                                     1
# Mathematics Chemistry                                             1
# Chemistry Major Acs Certified                                     1
# Hisotry English Physics Degree Minor Biological Sciences Chemistry General And Organic      1
# Chemistry Minor In Political Science                              1
# dtype: int64
# 193

# %%
##### IST records in LinkedIn but Not in Our Data
keywords = ['computer','information','info','tech','ist','is']
keywordsnot = ['management','health','education']
mgm = [bool(re.compile(r'(?i)\b(?:%s)\b' % ('|'.join(keywords))).search(major)) & \
       (not bool(re.compile(r'(?i)\b(?:%s)\b' % ('|'.join(keywordsnot))).search(major)))\
                      for major in education.Major]

print sum(mgm)
columnstowrite = ['FullName','StartYear','EndYear','Major','Degree']
# education[mgm][columnstowrite].to_csv('../IST_manual.csv',index=True)
IST_manual = pd.read_csv('../IST_manual.csv',index_col=0)
IST_manual.Match_or_Not[pd.isnull(IST_manual.Match_or_Not)] = 0
IST_manual = education[mgm][IST_manual.Match_or_Not.astype('bool')]
IST_manual.drop_duplicates(cols=['Index','File'],inplace = True, take_last=True)
matched_st = zip(manualMatchTable.Index_y.astype('int'), manualMatchTable.File.astype('float'))
IST_st = zip(IST_manual.Index, IST_manual.File)
print len(IST_manual)
sum([st not in matched_st for st in IST_st])
# Out:
# 547
# 308
# 162

# %%
##### Physics records in LinkedIn but Not in Our Data
keywords = ['physics']
mgm = [bool(re.compile(r'(?i)\b(?:%s)\b' % ('|'.join(keywords))).search(major))\
                      for major in education.Major]

print sum(mgm)
columnstowrite = ['FullName','StartYear','EndYear','Major','Degree']
# education[mgm][columnstowrite].to_csv('../pysics_manual.csv',index=True)
IST_manual = pd.read_csv('../pysics_manual.csv',index_col=0)
IST_manual.Match_or_Not[pd.isnull(IST_manual.Match_or_Not)] = 0
IST_manual = education[mgm][IST_manual.Match_or_Not.astype('bool')]
IST_manual.drop_duplicates(cols=['Index','File'],inplace = True, take_last=True)
matched_st = zip(manualMatchTable.Index_y.astype('int'), manualMatchTable.File.astype('float'))
IST_st = zip(IST_manual.Index, IST_manual.File)
print len(IST_manual)
sum([st not in matched_st for st in IST_st])
# Out:
# 24
# 11
# 9

# %%
keywords = ['math','mathmatics','mathematics','mathematic']
keywordsnot = ['education','teaching']
mgm = [bool(re.compile(r'(?i)\b(?:%s)\b' % ('|'.join(keywords))).search(major)) & \
       (not bool(re.compile(r'(?i)\b(?:%s)\b' % ('|'.join(keywordsnot))).search(major)))\
                      for major in education.Major]

print sum(mgm)
columnstowrite = ['FullName','StartYear','EndYear','Major','Degree']
# education[mgm][columnstowrite].to_csv('../math_manual.csv',index=True)
IST_manual = pd.read_csv('../math_manual.csv',index_col=0)
IST_manual.Match_or_Not[pd.isnull(IST_manual.Match_or_Not)] = 0
IST_manual = education[mgm][IST_manual.Match_or_Not.astype('bool')]
IST_manual.drop_duplicates(cols=['Index','File'],inplace = True, take_last=True)
matched_st = zip(manualMatchTable.Index_y.astype('int'), manualMatchTable.File.astype('float'))
IST_st = zip(IST_manual.Index, IST_manual.File)
print len(IST_manual)
sum([st not in matched_st for st in IST_st])
# Out:
# 76
# 43
# 27

# %%
keywords = ['chem','chemistry']
keywordsnot = ['education','teaching']
# mgm = [bool(re.compile(r'(?i)\b(?:%s)\b' % ('|'.join(keywords))).search(major)) & \
#        (not bool(re.compile(r'(?i)\b(?:%s)\b' % ('|'.join(keywordsnot))).search(major)))\
#                       for major in education.Major]

mgm = [bool(major.lower() == 'chemistry') for major in education.Major]
print sum(mgm)
columnstowrite = ['FullName','StartYear','EndYear','Major','Degree']
# education[mgm][columnstowrite].to_csv('../chem_manual.csv',index=True)
IST_manual = pd.read_csv('../chem_manual.csv',index_col=0)
IST_manual.Match_or_Not[pd.isnull(IST_manual.Match_or_Not)] = 0
IST_manual = education[mgm][IST_manual.Match_or_Not.astype('bool')]
IST_manual.drop_duplicates(cols=['Index','File'],inplace = True, take_last=True)
matched_st = zip(manualMatchTable.Index_y.astype('int'), manualMatchTable.File.astype('float'))
IST_st = zip(IST_manual.Index, IST_manual.File)
print len(IST_manual)
sum([st not in matched_st for st in IST_st])
# Out:
# 158
# 130
# 50

# %%
IST_manual[columnstowrite+['LastName','Index','File'，]][[st not in matched_st for st in IST_st]]
# Out:
#                     FullName StartYear EndYear  \
# 99                 Ali Anari      2009    2012
# 102                Ali Anari      2009    2012
# 327              Ben Handley      1999    2004
# 600             Chris Grosso      2002    2006
# 3667          Steven D Heyen      2010    2014
# 3884          Tony Cosentini      2008    2012
# 4778           Andriy Demkiv      2010    2011
# 6803            Connor Skiro      2011    2016
# 14209          Michael Fatal      2010    2014
# 15174            Patel Samir      2001    2004
# 15924             Rhea Borja      2002    2004
# 17237          Sophia Felder      2010    2014
# 17246       Sophia Salvatore      2008    2013
# 17397        Stephen Johnson      2007    2012
# 18205          Tom Fleischer      2000    2005
# 18294                Tou Can      2009    2013
# 18781          Winnie Cheung      2003    2005
# 114                Ali Anari      2009    2012
# 1329                Gary Joe      1997    2001
# 1567          Jack Tsigankov      2009    2012
# 1886     Joseph O AyoVaughan      2011    2015
# 3400            Sean Barrett      2005    2009
# 3403            Sean Barrett      2005    2009
# 4302         Alexios Chronis      1998    2003
# 5327            Bernard Best      2004    2007
# 7235            David Duffey      1997    2000
# 9043             Haidong Shi      2007    2010
# 11417      Karishma Wadhwani      2009    2012
# 12677           Logan Murphy      2010    2014
# 13907        Michael Hallman      1997    2001
# ...                      ...       ...     ...
# 18321        Victor Manzueta      2002    2006
# 74                 Ali Anari      2009    2012
# 434    Bradley DaviesRoberts      2004    2008
# 958             Dwayne Ghant      2001    2005
# 1072                 Ed Kern      2002    2005
# 1280              Ge Yan  闫格      2001    2004
# 1901            Joshua Kraft      1998    2002
# 1946        Jonathan Whiting      1999    2004
# 4689         Andrew Pawloski      2009    2013
# 11810     Kevin Rothenberger      2011    2015
# 11942           Kinjal Patel      1997    2002
# 14246           Molly Harper      2007    2010
# 16771            Shawn Moore      2000    2005
# 16853        Shirley Simmons      1998    2002
# 18008          Travis Warren      2007    2012
# 18357         Werawati Phang      2010    2013
# 1550             James Earls      2000    2003
# 3279             Sabil Ardie      2001    2005
# 3394              Sean Coker      2008    2012
# 4099      Adefolarin Adeleke      2011    2015
# 4710        Andrew Holsopple      2009    2013
# 7325             David Aaron      2004    2007
# 7510         David Struewing      2011    2015
# 7536              David Yoon      2011    2015
# 8713           Farouk Agbaje      2011    2016
# 9809           James Robison      2009    2013
# 11105      Jonathan Kirkland      2002    2006
# 12408             Kyle Welch      2006    2010
# 15191         Nicole Maalouf      2011    2015
# 18918                Xu Tang      2011    2014
#
#                                                 Major  \
# 99                                   Computer Science
# 102                                  Computer Science
# 327                 Computer And Information Sciences
# 600                                  Computer Science
# 3667               Information Science And Technology
# 3884                                 Computer Science
# 4778                                 Computer Science
# 6803                                 Computer Science
# 14209                                Computer Science
# 15174                        Science Computer Science
# 15924              Information Science And Technology
# 17237              Information Science And Technology
# 17246                Computer Science And Mathematics
# 17397                          Information Technology
# 18205                                Computer Science
# 18294                          Information Technology
# 18781                    Computer Information Science
# 114                                  Computer Science
# 1329                                 Computer Science
# 1567               Information Science And Technology
# 1886                                 Computer Science
# 3400               Information Science And Technology
# 3403               Information Science And Technology
# 4302                                 Computer Science
# 5327                                 Computer Science
# 7235                Computer And Information Sciences
# 9043                                 Computer Science
# 11417                          Information Technology
# 12677                                Computer Science
# 13907                                Computer Science
# ...                                               ...
# 18321                  Information Systems Technology
# 74                                   Computer Science
# 434                Information Science And Technology
# 958                Information Science And Technology
# 1072                                 Computer Science
# 1280                                 Computer Science
# 1901                                 Computer Science
# 1946               Information Science And Technology
# 4689                                 Computer Science
# 11810                                Computer Science
# 11942                          Information Technology
# 14246                  Information Science Technology
# 16771               Computer And Information Sciences
# 16853  Computer Scienceinformation Science Technology
# 18008              Information Science And Technology
# 18357                          Information Technology
# 1550                                 Computer Science
# 3279               Information Science And Technology
# 3394                  Information Sciences Technology
# 4099                           Information Technology
# 4710                                 Computer Science
# 7325                                 Computer Science
# 7510                                 Computer Science
# 7536                                 Computer Science
# 8713                                 Computer Science
# 9809                                 Computer Science
# 11105                          Information Technology
# 12408                          Information Technology
# 15191                    Computer Information Science
# 18918                                Computer Science
#
#                                         Degree       LastName  Index  File
# 99                         Bachelor Of Science          Anari     36     0
# 102                        Bachelor Of Science          Anari     37     0
# 327                                         Bs        Handley    139     0
# 600           Bachelor Of Applied Science Basc         Grosso    258     0
# 3667                    Bachelor Of Science Bs          Heyen   1530     0
# 3884                                        Bs      Cosentini   1629     0
# 4778                                        Bs         Demkiv   2054     0
# 6803                    Bachelor Of Science Bs          Skiro   3084     0
# 14209                   Bachelor Of Science Bs          Fatal   6822     0
# 15174                                       Bs          Samir   7319     0
# 15924               Bachelor Of Science Degree          Borja   7670     0
# 17237                      Bachelor Of Science         Felder   8324     0
# 17246                      Bachelor Of Science      Salvatore   8329     0
# 17397                   Bachelor Of Science Bs        Johnson   8411     0
# 18205                      Bachelor Of Science      Fleischer   8828     0
# 18294                         Bachelors Degree            Can   8875     0
# 18781                                       Bs         Cheung   9133     0
# 114                        Bachelor Of Science          Anari     48     1
# 1329                                 Bachelors            Joe    559     1
# 1567                    Bachelor Of Science Bs      Tsigankov    667     1
# 1886                          Bachelors Degree     AyoVaughan    795     1
# 3400                                        Bs        Barrett   1439     1
# 3403                                                  Barrett   1440     1
# 4302                                        Bs        Chronis   1855     1
# 5327                                        Na           Best   2379     1
# 7235                    Bachelor Of Science Bs         Duffey   3312     1
# 9043                                                      Shi   4218     1
# 11417                   Bachelor Of Science Bs       Wadhwani   5416     1
# 12677                   Bachelor Of Science Bs         Murphy   6064     1
# 13907                                       Ba        Hallman   6682     1
# ...                                        ...            ...    ...   ...
# 18321                                       Bs       Manzueta   8873     7
# 74                         Bachelor Of Science          Anari     37     8
# 434                     Bachelor Of Science Bs  DaviesRoberts    186     8
# 958                       Bachelors Of Science          Ghant    408     8
# 1072                                        Bs           Kern    462     8
# 1280                                  Bachelor             闫格    556     8
# 1901                    Bachelor Of Science Bs          Kraft    824     8
# 1946                                        Bs        Whiting    845     8
# 4689                      Bachelors Of Science       Pawloski   2058     8
# 11810                   Bachelor Of Science Bs   Rothenberger   5646     8
# 11942  Bachelor Of Business Administration Bba          Patel   5709     8
# 14246                      Bachelor Of Science         Harper   6877     8
# 16771                   Bachelor Of Science Bs          Moore   8171     8
# 16853                                       Bs        Simmons   8221     8
# 18008                   Bachelor Of Science Bs         Warren   8801     8
# 18357                                 Bachelor          Phang   8971     8
# 1550                                                    Earls    659     9
# 3279                       Bachelor Of Science          Ardie   1399     9
# 3394                       Bachelor Of Science          Coker   1448     9
# 4099                                                  Adeleke   1736     9
# 4710                    Bachelor Of Science Bs      Holsopple   2039     9
# 7325   Bachelor Of Business Administration Bba          Aaron   3348     9
# 7510                       Bachelor Of Arts Ba      Struewing   3436     9
# 7536                     Bachelors Of Sciences           Yoon   3450     9
# 8713                                                   Agbaje   4035     9
# 9809                    Bachelor Of Science Bs        Robison   4580     9
# 11105                   Bachelor Of Science Bs       Kirkland   5251     9
# 12408         Bachelor Of Applied Science Basc          Welch   5919     9
# 15191                      Bachelor Of Science        Maalouf   7310     9
# 18918                   Bachelor Of Science Bs           Tang   9192     9
#
# [162 rows x 8 columns]

# %%
# %pylab inline
# manualMatchTable = pd.read_csv('../manualMatchedTable.csv',index_col=0,dtype='object')
x = manualMatchTable.EndYear_x[manualMatchTable.Graduated_or_not.astype('int').astype('bool')]
y = studentInfo.EndYear[studentInfo.Graduated_or_not.astype('int').astype('bool')]
totalCounts = np.log2(x.value_counts()+1)
counts = np.log2(y.value_counts()+1)
k = len(counts)
fig, ax = plt.subplots()
width = 0.35
ind = np.arange(k)
rect1 = ax.bar(ind, counts.iloc[:k],width, color='r')
rect2 = ax.bar(ind+width, totalCounts.ix[counts.iloc[:k].index],width, color='b')
labels = counts.iloc[:k].index
# labels[pd.isnull(labels)] = labels[pd.isnull(labels)].index
plt.xticks(ind+2*width, labels, rotation = 45, ha='right')
for i in ind:
    plt.text(i+width, counts.values[i], \
             '%.2f'%(np.divide(totalCounts.ix[counts.iloc[:k].index], counts).values[i]),\
             ha='center')

plt.title('Sampling Bias of the Graduation Year for Graduated Students')
ax.set_ylabel('Log2 Number of students')
ax.set_xlabel('Graduation Year')
plt.legend((rect1[0],rect2[0]),('Grad_all','Grad_matched'))

# plt.title('Bias of the Last Recorded Year for nonGraduated Students')
# ax.set_ylabel('Log2 Number of students')
# ax.set_xlabel('Last Recorded Year')
# plt.legend((rect1[0],rect2[0]),('NonGrad_all','NonGrad_matched'))

plt.gcf().tight_layout()
plt.subplots_adjust(top=0.9)

# %%
# %pylab inline
width = 0.35
totalCounts = studentGrad.GradMjReName
totalCounts = np.log2(totalCounts.value_counts()+1)
counts = manualGrad.GradMjReName
counts = np.log2(counts.value_counts()+1)
k = np.linspace(0, 34, num=35)
# k = np.linspace(31, 60, num = 30)
fig, ax = plt.subplots()
ind = k
rect1 = ax.bar(ind, totalCounts.iloc[k], width, color='r')
rect2 = ax.bar(ind+width, counts.ix[totalCounts.iloc[k].index],width, color='b')
labels = totalCounts.iloc[k].index
plt.xticks(ind+2*width, labels, rotation = 45, ha='right')
for i in ind:
    plt.text(i+width, totalCounts.values[i], \
             '%.2f'%(np.divide(counts.ix[totalCounts.index], totalCounts).values[i]),\
             ha='center')

plt.title('Bias of Majors for Graduated Students')
ax.set_ylabel('Log2 Number of students')
ax.set_xlabel('Major')
plt.legend((rect1[0],rect2[0]),('Grad_all','Grad_matched'))

plt.gcf().tight_layout()
plt.subplots_adjust(top=0.9)
fig.set_size_inches(20,20.5)
# plt.savefig('pic/entrymajor_vs_endmajor.png')
# plt.set_xticks(ind + 0.5/2)
# ax.set_xticklabels(EndMj.iloc[:10].index)

# %%
years = [str(y) for y in range(1998,2011)]
majors = totalCounts.iloc[:34].index
tnum = pd.DataFrame(columns=majors, index=years)
mnum = pd.DataFrame(columns=majors, index=years)
data = {key:gr.EndYear.value_counts() for key,gr in studentGrad.groupby(['GradMjReName'])}
data2 = {key:gr.EndYear_x.value_counts() for key,gr in manualGrad.groupby(['GradMjReName'])}
for major in majors:
    if major in data.keys(): tnum[major].ix[data[major].index] = data[major].values
    if major in data2.keys(): mnum[major].ix[data2[major].index] = data2[major].values
tnum[pd.isnull(tnum)] = 0
mnum[pd.isnull(mnum)] = 0

# %%
# %pylab inline
# manualMatchTable = pd.read_csv('../manualMatchedTable.csv',index_col=0,dtype='object')
major = majors[0]
for index,major in enumerate(majors[:20]):
    totalCounts = np.log2(tnum[major].astype('float')+1)
    counts = np.log2(mnum[major].astype('float')+1)
    k = len(counts)
    fig, ax = plt.subplots()
    width = 0.35
    ind = np.arange(k)
    rect1 = ax.bar(ind, totalCounts,width, color='r')
    rect2 = ax.bar(ind+width, counts,width, color='b')
    labels = totalCounts.index
    # labels[pd.isnull(labels)] = labels[pd.isnull(labels)].index
    plt.xticks(ind+2*width, labels, rotation = 45, ha='right')
    for i in ind:
        plt.text(i+width, totalCounts.values[i], \
                 '%.2f'%(np.divide(counts, totalCounts).values[i]),\
                 ha='center')

    plt.title('%s Sampling Bias in each year' % major)
    ax.set_ylabel('Log2 Number of students')
    ax.set_xlabel('Graduation Year')
    plt.legend((rect1[0],rect2[0]),('Grad_all','Grad_matched'),loc='best')

    # plt.title('Bias of the Last Recorded Year for nonGraduated Students')
    # ax.set_ylabel('Log2 Number of students')
    # ax.set_xlabel('Last Recorded Year')
    # plt.legend((rect1[0],rect2[0]),('NonGrad_all','NonGrad_matched'))

    plt.gcf().tight_layout()
    plt.subplots_adjust(top=0.9)
    plt.savefig('../pic/%d %s bias in each year.png' % (index, major))

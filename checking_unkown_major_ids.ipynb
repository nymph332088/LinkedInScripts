# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pylab as plt

# %%
studentInfo = pd.read_csv('studentInfo4.csv',dtype=object)
print studentInfo.shape
majorDict = pd.read_csv('majordict.csv', dtype=object)
majorDict.index = majorDict.ID
# Out:
# (10978, 19)

# %%
# %pylab inline
width = 0.35
k = 20
StMj = studentInfo.Entry_Major
# StMj = StMj.value_counts().iloc[:k]
StMj = np.log2(StMj.value_counts().iloc[:k]+1)
EndMj = studentInfo.EndMj
# EndMj = EndMj.value_counts()
EndMj = np.log2(EndMj.value_counts()+1)

fig, ax = plt.subplots()
ind = np.arange(k)
rect1 = ax.bar(ind, StMj,width, color='r')
rect2 = ax.bar(ind+width, EndMj.ix[StMj.index],width, color='b')
labels = majorDict.ix[StMj.iloc[:k].index].Name
labels[pd.isnull(labels)] = labels[pd.isnull(labels)].index
plt.xticks(ind+2*width, labels, rotation = 45, ha='right')
ax.set_ylabel('Log2 Number of students')
plt.legend((rect1[0],rect2[0]),('EntryMajor','EndMajor'))
plt.gcf().tight_layout()
plt.savefig('pic/entrymajor_vs_endmajor.png')
# plt.set_xticks(ind + 0.5/2)
# ax.set_xticklabels(EndMj.iloc[:10].index)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab inline
width = 0.35
k = 20
StMj = studentInfo.EndMj
# StMj = StMj.value_counts().iloc[:k]
StMj = np.log2(StMj.value_counts().iloc[:k]+1)
EndMj = studentInfo.Entry_Major
# EndMj = EndMj.value_counts()
EndMj = np.log2(EndMj.value_counts()+1)

fig, ax = plt.subplots()
ind = np.arange(k)
rect1 = ax.bar(ind+width, StMj,width, color='b')
rect2 = ax.bar(ind, EndMj.ix[StMj.index],width, color='r')
labels = majorDict.ix[StMj.iloc[:k].index].Name
labels[pd.isnull(labels)] = labels[pd.isnull(labels)].index
plt.xticks(ind+2*width, labels, rotation = 45, ha='right')
ax.set_ylabel('Log2 Number of students')
plt.legend((rect2[0],rect1[0]),('EntryMajor','EndMajor'))
plt.gcf().tight_layout()
# plt.savefig('pic/entrymajor_vs_endmajor.png')
# plt.set_xticks(ind + 0.5/2)
# ax.set_xticklabels(EndMj.iloc[:10].index)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
st_mathced_Info = studentInfo[studentInfo.NumMT == '1']
st_mathced_Info.All_majors[pd.isnull(st_mathced_Info.All_majors)] = ''
allIdsInRecord = np.unique([y for x in st_mathced_Info.All_majors.values for y in x.split(';')])
totalIdsForMatch = majorDict.ix[allIdsInRecord].ID
missingIds = totalIdsForMatch[pd.isnull(totalIdsForMatch)].index

# %%
mid_st_dict = {}
for id in missingIds:
    mid_st_dict[id] = [sind for sind in st_mathced_Info.index if id in st_mathced_Info.ix[sind].All_majors.split(';')]

# %%
mjnmLinkin= {}
for key in mid_st_dict.keys():
    # 5th column in file
    mjnmLinkin[key] = []
    for st in mid_st_dict[key]:
        fn = int(float(st_mathced_Info.ix[st].MTResults.split(';')[0]))
        ln = int(float(st_mathced_Info.ix[st].MTResults.split(';')[1]))
        mjnmLinkin[key].append(open('part-%05d' %(fn),'rb').readlines()[ln].split('\t')[5])

# %%
import csv
writer = csv.writer(open('missingmajor.csv', 'wb'))
for key, value in mjnmLinkin.items():
   writer.writerow([key, value])

# %%
st_mathced_Info = studentInfo[studentInfo.NumMT == '1']
st_mathced_Info.shape

# %pylab inline
width = 0.35
k = 20
StMj = studentInfo.EndMj
# StMj = StMj.value_counts().iloc[:k]
StMj = np.log2(StMj.value_counts().iloc[:k]+1)
EndMj = st_mathced_Info.EndMj
# EndMj = EndMj.value_counts()
EndMj = np.log2(EndMj.value_counts()+1)

fig, ax = plt.subplots()
ind = np.arange(k)
rect1 = ax.bar(ind, StMj,width, color='r')
rect2 = ax.bar(ind+width, EndMj.ix[StMj.index],width, color='b')
labels = majorDict.ix[StMj.iloc[:k].index].Name
labels[pd.isnull(labels)] = labels[pd.isnull(labels)].index
plt.xticks(ind+2*width, labels, rotation = 45, ha='right')
ax.set_ylabel('Log2 Number of students')
ax.set_xlabel('Top 20 final majors for overall and linkedin students') 
plt.legend((rect1[0],rect2[0]),('Overall','In LinkedIn'))
plt.gcf().tight_layout()
plt.savefig('pic/major_bias.png')
# plt.set_xticks(ind + 0.5/2)
# ax.set_xticklabels(EndMj.iloc[:10].index)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import re
def findWholeWord(w):
    return re.compile(r'\b({0})\b'.format(w), flags=re.IGNORECASE).search

# bioch_sts = []

# for i in range(0,10):
#     for ln, x in enumerate(open('part-%05d-namemap' %(i),'rb').readlines()):
#         major = x.split('\t')[5]
#         duration = x.split('\t')[6]
matched_st = [tuple(x.split(';')[:2]) for x in st_mathced_Info.MTResults]
names = ['biochemistry','pharmacy','biology', 'psychology','kinesiology','anthropology','nursing','marketing','accounting']        
results = {}
for name in names:
    linkin_st = [(str(i),str(ln)) for i in range(0,10)  for ln, x in enumerate(open('part-%05d' %(i),'rb').readlines())\
             if name in x.split('\t')[5].lower()]
    notmatched = [x for x in linkin_st if x not in matched_st]
    results[name] = [len(linkin_st),len(notmatched),len(linkin_st) - len(notmatched)]

# %%
studentInfo = pd.read_csv('studentInfo5.csv',sep='\t')
studentInfo
print len(studentInfo)
education = [ pd.read_csv('part-%05d-education.csv' %i, sep='\t') for i in range(0,10)]
print len(education)
education = [edu[~pd.isnull(edu.FullName)] for edu in education]
for i, edu in enumerate(education):
    edu['File'] = np.zeros((len(edu),)) + i
education = pd.concat(education,axis=0)
print len(education)
templeStu = education[[bool(findWholeWord('temple')(uni)) for uni in  education.University]]
print len(templeStu.groupby(['File','Index']))
recordedStu = templeStu[(templeStu.StartYear.astype('float')<=2010) & (templeStu.StartYear.astype('float')>=1989)]
print len(recordedStu.groupby(['File','Index']))
recordedStu.Major[pd.isnull(recordedStu.Major)] = ''
recordedStu.Degree[pd.isnull(recordedStu.Degree)]= ''
bachelorStu = recordedStu
degrees = [''.join(x.split('.')) for x in bachelorStu.Degree]
masterOrPhD = []
for stdg in degrees:
    mas = False
    for dg in mst:
        if(findWholeWord(dg)(stdg)):
            mas = True
    masterOrPhD.append(mas)
bachelorStu = bachelorStu[~ np.array(masterOrPhD)]
print len(bachelorStu.groupby(['File','Index']))
# Out:
# 10978
# 10
# 186720
# 81672
# 41402
# 33905

# %%
names = ['physics','math','mathematics','chemistry']
st_mathced_Info = studentInfo[studentInfo.NumMT != 0]
matched_st = [tuple(x.split(';')[:2]) for x in st_mathced_Info.MTResults]
recordedStu.Major[pd.isnull(recordedStu.Major)] = ''
recordedStu.Degree[pd.isnull(recordedStu.Degree)]= ''
results = {}
mst = ['master','MA', 'MS', 'MEd', 'MSc', 'MEB', 'MDes', 'MNCM', 'MSN', \
       'MSW', 'MPA', 'MPC', 'MPP','MPH', 'MC', 'MCA', 'MCouns', 'MLA', 'MLIS', 'MDiv', \
       'ALM', 'MiM', 'MBA', 'MBA Tech', 'MCom', 'MBus', 'MI', 'PSM', \
       'MEng', 'MMath', 'MPhys', 'MPsych', 'MSci', 'MChem', 'MBiol', 'MGeol','doctor','phd','ph d','dphi']
for name in names:
    isMajorMatch = [(bool(findWholeWord(name)(major)) or bool(findWholeWord(name)(degree))) and \
                    (not bool(findWholeWord('education')(major)))\
                    for (major,degree) in zip(recordedStu['Major'].values,recordedStu['Degree'].values)]
    majorStu = recordedStu[isMajorMatch]
    degrees = [''.join(x.split('.')) for x in majorStu.Degree]
    masterOrPhD = []
    for stdg in degrees:
        mas = False
        for dg in mst:
            if(findWholeWord(dg)(stdg)):
                mas = True
        masterOrPhD.append(mas)
    majorStu = majorStu[~ np.array(masterOrPhD)]
    
#     flnames= zip([stnm.split()[0] for stnm in studentInfo.STName.values],\
#                  [stnm.split()[-1] for stnm in studentInfo.STName.values])
#     isNameMatch = []
#     for stnm in majorStu.FullName:
#         isNameMatch.append(bool(sum([bool(findWholeWord(fn)(stnm)) &\
#                                      bool(findWholeWord(ln)(stnm)) for (fn,ln) in flnames])))
    
#     matchStu = majorStu[isNameMatch]
    linkin_st = zip(majorStu['File'].astype('int').values, majorStu['Index'].values)
    linkin_st = [(str(i),str(ln)) for (i,ln) in linkin_st]
#     stfn = [ for x in ]
#     matched_st = zip(matchStu['File'].astype('int').values, matchStu['Index'].values)
#     matched_st = [(str(i),str(ln)) for (i,ln) in matched_st]
    notmatched = [x for x in linkin_st if x not in matched_st]
    results[name] = [len(linkin_st),len(notmatched),len(linkin_st) - len(notmatched)]

# %%
results
# Out:
# {'chemistry': [250, 138, 112],
#  'math': [9, 8, 1],
#  'mathematics': [99, 70, 29],
#  'physics': [34, 27, 7]}

# %%
results
# Out:
# {'chemistry': [251, 139, 112],
#  'math': [18, 17, 1],
#  'mathematics': [120, 90, 30],
#  'physics': [36, 29, 7]}

# %%
results
# Out:
# {'biology': [718, 453, 265],
#  'chemistry': [327, 218, 109],
#  'math': [21, 20, 1],
#  'physics': [61, 55, 6]}

# %%
results
# Out:
# {'biology': [607, 347, 260],
#  'chemistry': [251, 145, 106],
#  'math': [18, 17, 1],
#  'physics': [36, 30, 6]}

# %%
name = 'physics'
isMajorMatch = [(bool(findWholeWord(name)(major)) or bool(findWholeWord(name)(degree))) and \
                (not bool(findWholeWord('education')(major)))\
                for (major,degree) in zip(recordedStu['Major'].values,recordedStu['Degree'].values)]
majorStu = recordedStu[isMajorMatch]
degrees = [''.join(x.split('.')) for x in majorStu.Degree]
masterOrPhD = []
for stdg in degrees:
    mas = False
    for dg in mst:
        if(findWholeWord(dg)(stdg)):
            mas = True
    masterOrPhD.append(mas)
majorStu = majorStu[~ np.array(masterOrPhD)]
# flnames= zip([stnm.split()[0] for stnm in studentInfo.STName.values],\
#              [stnm.split()[-1] for stnm in studentInfo.STName.values])
# isNameMatch = []
# for stnm in majorStu.FullName:
#     isNameMatch.append(bool(sum([bool(findWholeWord(fn)(stnm)) &\
#                                  bool(findWholeWord(ln)(stnm)) for (fn,ln) in flnames])))
# matchStu = majorStu[isNameMatch]

linkin_st = zip(majorStu['File'].astype('int').values, majorStu['Index'].values)
linkin_st = [(str(i),str(ln)) for (i,ln) in linkin_st]
#     stfn = [ for x in ]
unmatchStu = majorStu[~np.array([(i,ln) in matched_st for (i,ln) in linkin_st])]
matched_st = zip(matchStu['File'].astype('int').values, matchStu['Index'].values)
matched_st = [(str(i),str(ln)) for (i,ln) in matched_st]
notmatched = [x for x in linkin_st if x not in matched_st]
results[name] = [len(linkin_st),len(notmatched),len(matched_st)]

# %%
degree = [''.join(x.split('.')) for x in recordedStu.Degree]
major = [''.join(x.split('.')) for x in recordedStu.Major]

# %%
a = pd.Series(degree).value_counts().index.tolist()
a.sort()
a
# Out:
# ['',
#  '"BS"',
#  '"Bachelor of Arts',
#  '"Bachelor of Communications"',
#  '"Bachelor of Science" BA Business Administration',
#  '"Bachelor of Science",',
#  '"Bachelors of Arts"',
#  '"Doctor of Podiatric Medicine" or "DPM"',
#  '"Masters of Music Therapy (MMT)",',
#  "'Study Abroad'",
#  '(BA),',
#  '(BBA),',
#  ', Computer Information and Sciences',
#  '-',
#  '- Study Abroad Program in Rome, Italy',
#  '108 credits,',
#  '12 doctoral credits,',
#  '120 Hour Certification Course: Pennsylvania Licensed NHA',
#  '15 years',
#  '15 years towards MBA,',
#  '16 Semester Hours toward MA',
#  '1993',
#  '1993,',
#  '1996,',
#  '1997',
#  '1998,',
#  '2 years,',
#  '2000,',
#  '2002',
#  '2003\tBA,',
#  '2003\tPhD; MA',
#  '2004\tPhD; MA',
#  '2005 Bachelor of Arts',
#  '2007',
#  '2007,',
#  '2008',
#  '2009 BS,',
#  '2010\tBA,',
#  '2010\tBA; Certificate',
#  '2010,',
#  '2011',
#  '2011\tBachelor',
#  '2012 Bachelor of Arts,',
#  '2014',
#  '22 College Credits',
#  '24 Hours Graduate Studies',
#  '30+hours',
#  '33 hours completed and passed of PhD in Spanish',
#  '45 credits toward BS,',
#  '4y',
#  '5 yr, Bachelor of Architecture (BArch),',
#  '5-Year Bachelor,',
#  '52 Credits Earned,',
#  'A+ / N+ Certification,',
#  'A+,',
#  'AA',
#  'AA,',
#  'ABC (all but certification),',
#  'ABD',
#  'ABD (PhD),',
#  'ABD - Doctorate in Health Studies,',
#  'ABD PhD',
#  'ABD PhD,',
#  'ABD for PhD,',
#  'ABD,',
#  'ABD/PhD,',
#  'ACT 120',
#  'AEGD',
#  'AEGD Residency',
#  'AEGD certificate,',
#  'AS',
#  'AS&BS,',
#  'AS,',
#  'ASST',
#  'AbD',
#  'AbD,',
#  'Abroad Program,',
#  'Abroad Student',
#  'Accelerated BS to MS,',
#  'Accounting',
#  'Accounting & a Minor in Rhetoric & Comm',
#  'Accounting / Risk Management and Insurance',
#  'Accounting Concentration,',
#  'Accounting and Finance,',
#  'Accounting and QuickBooks',
#  'Accounting,',
#  'Accounting, Risk Management and Insurance',
#  'Achieved 6 advanced degree credits',
#  'Act 120 Certification',
#  'Act 120,',
#  'Act 40',
#  'Acting; BA',
#  'Actuarial Science',
#  'Adjunct Prof',
#  'Administrative Certification,',
#  'Adult Night Classes',
#  'Adult and Organizational Development',
#  'Advance Certificate in Culturally Competent Human services,',
#  'Advanced Certificate,',
#  "Advanced Master's degree",
#  'Advertising',
#  'Advertising - design,',
#  'Advertising Art Direction,',
#  'Advertising,',
#  'Advertising, Art Minor,',
#  'African-American Studies',
#  "Agent's License,",
#  'All But Dissertation ABD',
#  'Anesthesiology Residency Certificate',
#  'Anthropology',
#  'Anthropology,',
#  'Anticipated BA',
#  'Anticipated MEd',
#  'Applied Communications',
#  'Applied Organizational Development',
#  'Architecture',
#  'Architecture,',
#  'Art',
#  'Art Direction',
#  'Art Education,',
#  'Art History,',
#  'Art Minor',
#  'Art,',
#  'Art-Cert,',
#  'Arts',
#  'Asian Studies',
#  'Assoc',
#  'Associate Degree in Business Adminstration from Bucks county community college,',
#  'Associate Science',
#  'Associate of Applied Science AAS',
#  'Associate of Arts',
#  'Associate of Arts (AA)',
#  'Associate of Arts (AA),',
#  'Associate of Office Administration,',
#  'Associate of Science (AS)',
#  "Associate's Degree",
#  "Associate's Degree,",
#  "Associate's degree",
#  "Associate's degree - equivalent",
#  "Associate's degree,",
#  'Associate,',
#  'Associates',
#  'Associates Degree',
#  'Associates Degree,',
#  'Associates of Advertising',
#  'Associates of Science',
#  'Associates,',
#  'Attendance',
#  'Attended',
#  'Attended the History PhD Program',
#  'August 2012 Bachelor of Arts',
#  'Awarded Graduate Level Certification,',
#  'B',
#  'B A',
#  'B A,',
#  'B ARCH,',
#  'B Arch',
#  'B Arch,',
#  'B Architecture,',
#  'B Mus',
#  'B S,',
#  'B S;,',
#  'B Sc Eng,',
#  'B Sc,',
#  'B of arch',
#  'B), BA',
#  'B-Arch',
#  'B-Arch Prof',
#  'B-Arch,',
#  'B/A,',
#  'B/A, Strategic and Organizational Communication,',
#  'BA',
#  'BA & MA,',
#  'BA (Magna Cum Laude)',
#  'BA (Summa Cum Laude),',
#  'BA (cum laude)',
#  'BA (expected)',
#  'BA (summa cum laude)',
#  'BA (with Honors)',
#  'BA (with honors),',
#  'BA - Anthropology',
#  'BA - Applied Communication',
#  'BA - Arts,',
#  'BA - Fox School of Business,',
#  'BA - Pastoral Studies',
#  'BA - Political Science / History Minor,',
#  'BA - Strategic and Organizational Communications',
#  'BA - Tyler School of Art',
#  'BA - cum laude',
#  'BA - summa cum laude',
#  'BA Adult Organizational Development (AOD),',
#  'BA Advertising',
#  'BA Advertising,',
#  'BA Anthropology,',
#  'BA Applied Communications',
#  'BA Architecture',
#  'BA Art History',
#  'BA Arts & Science,',
#  'BA Arts, Journalism,',
#  'BA Asian Studies',
#  'BA Bible',
#  'BA Broadcast Telecommunications and Mass Media',
#  'BA Broadcast, Telecommunications, and Mass Media',
#  'BA Broadcasting, Telecommunication, and Mass Media,',
#  'BA Broadcasting, Telecommunications, Mass Media,',
#  'BA Business Admin',
#  'BA Business Admin and Marketing',
#  'BA Business Admin,',
#  'BA Business Administration',
#  'BA Business Administration,',
#  'BA Business,',
#  'BA CJ',
#  'BA Chemistry',
#  'BA Communication',
#  'BA Communications',
#  'BA Communications,',
#  'BA Communications, Advertising, Account Managment at Temple University',
#  'BA Criminal Justice',
#  'BA Criminal Justice,',
#  'BA Cum Laude',
#  'BA Degree,',
#  'BA Degrees,',
#  'BA Elem Ed,',
#  'BA Elementary Education',
#  'BA English',
#  'BA English BS Secondary Education',
#  'BA English,',
#  'BA Film and Media Arts,',
#  'BA Finance',
#  'BA Health Science',
#  'BA History',
#  'BA History,',
#  'BA Journalism',
#  'BA Journalism,',
#  'BA Journalism, Public Relations and Advertising',
#  'BA Journalism/Advertising,',
#  'BA Liberal Arts',
#  'BA MS,',
#  'BA Magna Cume Laude in Communications,',
#  'BA Media Studies & Production,',
#  'BA Music Education',
#  'BA Music,',
#  'BA Photojournalism,',
#  'BA Political Science with specialization in Political Economics,',
#  'BA Professional',
#  'BA Psychology',
#  'BA Psychology,',
#  'BA Risk Management and Insurance and BA Business Law,',
#  'BA Science,',
#  'BA Secondary Education,',
#  'BA Secondary Education, Social Studies',
#  'BA Sociology',
#  'BA Spanish',
#  'BA Spanish,',
#  'BA Speech and Theater,',
#  'BA Strategic and Organizational Communication',
#  'BA Strategic and Organizational Communication with Public Relations emphasis',
#  'BA Strategic and Organizational Communication,',
#  'BA Theatre',
#  'BA and JD',
#  'BA and MEd,',
#  'BA and MM,',
#  'BA candidate,',
#  'BA computer science,',
#  'BA degree,',
#  'BA in Accounting',
#  'BA in Advertising',
#  'BA in Advertising with a minor in Art',
#  'BA in Advertising,',
#  'BA in Broadcast Journalism',
#  'BA in Business Administration',
#  'BA in Business,',
#  'BA in Classics',
#  'BA in Communications',
#  'BA in Communications and Theater',
#  'BA in Communications and Theatre',
#  'BA in Communications,',
#  'BA in Communications, Fox School of Business',
#  'BA in Education/Social Studies,',
#  'BA in English Literature,',
#  'BA in English,',
#  'BA in Film and Media Arts',
#  'BA in Film and Media Studies,',
#  'BA in Graphic Design and Fine Art',
#  'BA in History',
#  'BA in Journalism, Magazine,',
#  'BA in Journalism, Public Relations & Advertising',
#  'BA in Liberal Arts',
#  'BA in Magazine Journalism',
#  'BA in Marketing and International Business',
#  'BA in Philosophy, BBA in Finance,',
#  'BA in Psychology',
#  'BA in STHM',
#  'BA in School of Communications and Theatre',
#  'BA in Theater,',
#  "BA in Women's,",
#  'BA in psychology',
#  'BA magna cum laude,',
#  'BA mass communications',
#  'BA of Arts,',
#  'BA of Broadcasting, Telecommunications, Mass Media with a minor is Business Management',
#  'BA of Business Administration,',
#  'BA of Business Admnistration',
#  'BA of Business,',
#  'BA of Communications',
#  'BA of Journalism',
#  'BA of Psychology,',
#  'BA of Science,',
#  'BA,',
#  'BA, Advertising',
#  'BA, Broadcast Journalism',
#  'BA, Broadcasting, Telecommunications',
#  'BA, Cum Laude',
#  'BA, Cum Laude,',
#  'BA, Honors Program,',
#  'BA, International Business',
#  'BA, Journalism',
#  'BA, Journalism Post-Baccalaureate Certificate, Editing,',
#  'BA, Journalism and BA, Film & Media Arts',
#  'BA, Journalism,',
#  'BA, MBA,',
#  'BA, MEd',
#  'BA, MEd,',
#  'BA, Magna Cum Laude',
#  'BA, Magna Cum Laude,',
#  'BA, Magna cum laude,',
#  'BA, News-Editorial Journalism',
#  'BA, Political Science',
#  'BA, Psychology',
#  'BA, Public Relations',
#  'BA, School of Communications',
#  'BA, Strategic and Organizational Communications,',
#  'BA, Summa Cum Laude',
#  'BA, Summa Cum Laude,',
#  'BA, Summa Cum Laude, Feb 2006',
#  'BA, Summa Cum Laude, Film And Media Arts,',
#  'BA, Summa cum laude',
#  'BA, Theatre',
#  'BA, University Honors Program,',
#  'BA, cum laude',
#  'BA, cum laude,',
#  'BA, magna cum laude',
#  'BA, magna cum laude,',
#  'BA, summa cum laude',
#  'BA, summa cum laude,',
#  'BA- 1994,',
#  'BA- Music Composition,',
#  'BA-Economics; BBA,',
#  'BA-FMA',
#  'BA-Journalism,',
#  'BA/BS,',
#  'BA; BA,',
#  'BA; BS,',
#  "BA; Bachelor's,",
#  'BA; Degree,',
#  'BA; Graduate',
#  'BA; Honors',
#  'BA; Liberal Arts,',
#  'BA; School,',
#  'BA; coursework,',
#  'BA; work,',
#  'BAA',
#  'BAA Business Admin',
#  'BAA,',
#  'BACHELOR',
#  'BACHELOR OF ARTS',
#  'BACHELOR OF ARTS,',
#  'BACHELOR OF OF BUSINESS ADMINISTRATION',
#  'BACHELOR OF SCIENCE',
#  'BACHELOR,',
#  'BACHELORS OF ARTS',
#  'BACHELORS OF SCIENCE,',
#  'BACHLOR OFARTS,',
#  'BARCH',
#  'BARCH Prof,',
#  'BARCH,',
#  'BAS',
#  'BAS,',
#  'BAr',
#  'BArch',
#  'BArch,',
#  'BBA',
#  'BBA (Magna Cum Laude)',
#  'BBA - Accounting',
#  'BBA - Acctg,',
#  'BBA - Economics,',
#  'BBA - Magna Cum Laude',
#  'BBA - The Fox School of Business,',
#  'BBA - magna cum laude,',
#  'BBA Accounting,',
#  'BBA Business',
#  'BBA Candidate',
#  'BBA Finance',
#  'BBA United States',
#  'BBA in Accounting',
#  'BBA in Accounting,',
#  'BBA in Finance',
#  'BBA in Human Resource Management,',
#  'BBA in MIS,',
#  'BBA in Marketing',
#  'BBA w/ Honors,',
#  'BBA with Honors,',
#  'BBA | MS | CPA Candidacy 2014,',
#  'BBA,',
#  'BBA, BS,',
#  'BBA, Bachelors of Business Administration',
#  'BBA, Cum Laude',
#  'BBA, Honors',
#  'BBA, Magna Cum Laude',
#  'BBA, Marketing Exchange Student',
#  'BBA, Minor,',
#  'BBA, Risk Management and Insurance',
#  'BBA, magna cum laude',
#  'BBA, magna cum laude,',
#  "BBA- Bachelor's of Business Administration,",
#  'BBA-MIS',
#  'BBA/ Cum Laude,',
#  'BBA/ HR Certification,',
#  'BBA/ MBA,',
#  'BBA/MBA',
#  'BBA: Economics,',
#  'BBA: Marketing Management - Temple University Fox School of Business',
#  'BBA; BBA',
#  'BBM',
#  'BBS',
#  'BBS,',
#  'BBa,',
#  'BCABA,',
#  'BCOMN',
#  'BCaBA coursework',
#  'BE',
#  'BEd',
#  'BEd,',
#  'BFA',
#  'BFA - Painting',
#  'BFA Cum Laude,',
#  'BFA Graphic and Interactive Design',
#  'BFA Graphic and Interactive Design with Art Education Concentration',
#  'BFA Jazz Saxophone',
#  'BFA and Minor in Art History,',
#  'BFA in Printmaking with and Art Education Concentration',
#  'BFA in painting with teaching certficate,',
#  'BFA,',
#  'BFA, BA',
#  'BFA, Graphic and Interactive Design',
#  'BFA, MFA',
#  'BLA',
#  'BLA,',
#  'BM',
#  'BM Bachelors in Music,',
#  'BM Flute Performance,',
#  'BM Viola Performance and Music Education',
#  'BM in Music Education',
#  'BM,',
#  'BM, MM',
#  'BM, summa cum laude',
#  'BMA,',
#  'BME',
#  'BMMEd,',
#  'BMus,',
#  'BMusic,',
#  'BOA',
#  'BOS',
#  'BS',
#  'BS & BA',
#  'BS (Honors),',
#  'BS (magna cum laude),',
#  'BS ,',
#  'BS - Biology',
#  'BS - Computer Enginerring',
#  'BS - Electrical Engineering',
#  'BS - Electrical Engineering,',
#  'BS - STHM',
#  'BS - Sociology,',
#  'BS Accounting',
#  'BS Arch',
#  'BS Arch & Art Minor',
#  'BS Arch,',
#  'BS Architecture',
#  'BS Bible',
#  'BS Bible,',
#  'BS Biology',
#  'BS Biology,',
#  'BS Busines Administration,',
#  'BS Business Admin',
#  'BS Business Administration',
#  'BS Business Administration,',
#  'BS Business w',
#  'BS Business,',
#  'BS CCET',
#  'BS Chemistry,',
#  'BS Civil Construction Engineering Technology,',
#  'BS Civil Construction Engineering and Technology',
#  'BS Civil Engineering',
#  'BS Civil Engineering concentrating in Environmental Studies',
#  'BS Comminications, BS Liberal Arts',
#  'BS Degree',
#  'BS ED',
#  'BS ED,',
#  'BS Early Childhood Education,',
#  'BS Early childhood/Elementary Education',
#  'BS Earth and Environmental Sciences',
#  'BS Economics',
#  'BS Ed',
#  'BS Ed,',
#  'BS Education',
#  'BS Education,',
#  'BS Electrical Engineering',
#  'BS Electrical Engineering,',
#  'BS Elementary Education,',
#  'BS Elementary and Special Education',
#  'BS Engineering',
#  'BS Engineering,',
#  'BS Environmental Engineering, MS Environmental Health Industrial Hygiene',
#  'BS Exercise Physiology',
#  'BS Exercise Science,',
#  'BS HIM',
#  'BS Health Information Management',
#  'BS Health phys ed Temple University/ Master of Ed',
#  'BS Horticulture,',
#  'BS Hospitality',
#  'BS In Health Studies',
#  'BS Information Science & Technology',
#  'BS Information Science & Technology; General Business Studies (Minor)',
#  'BS Information Science Technology,',
#  'BS Information Science and Technology',
#  'BS Interdisciplinary Studies',
#  'BS Kinesiology',
#  'BS Kinesiology, Business',
#  'BS LA,',
#  'BS Landscape Architecture',
#  'BS MET,',
#  'BS Marketing',
#  'BS Mechanical Engineering',
#  'BS Pastoral Studies',
#  'BS Pharm',
#  'BS Pharmacy',
#  'BS Pharmacy,',
#  'BS Public Health',
#  'BS Public Health,',
#  'BS RiskManagement and Insurance; Legal Studies,',
#  'BS Sci Ed,',
#  'BS Science',
#  'BS Science,',
#  'BS Secondary Education/English,',
#  'BS Sport and Recreation Management',
#  'BS Sport and Recreation Management,',
#  'BS Summa Cum Laude,',
#  'BS Tourism and Hospitality Management',
#  'BS Youth Min',
#  'BS and BA',
#  'BS and BBA',
#  'BS and Distinction,',
#  'BS degree',
#  'BS education',
#  'BS in Arch',
#  'BS in Architecture',
#  'BS in Architecture,',
#  'BS in Biology',
#  'BS in Biology,',
#  'BS in Business Administration,',
#  'BS in Chemistry',
#  'BS in Civil Construction Engineering Technology AND Bachelor of Art in Digital Media',
#  'BS in Civil Engineering,',
#  'BS in Communication',
#  'BS in Community and Regional Planning',
#  'BS in Computer Information Systems',
#  'BS in Computer and Information Science',
#  'BS in Education',
#  'BS in Education,',
#  'BS in Electrical Engineering',
#  'BS in Elementary Education',
#  'BS in Elementary/Special Education',
#  'BS in Engineering',
#  'BS in Engineering,',
#  'BS in Health Information Management',
#  'BS in Pharmacy',
#  'BS in Pharmacy,',
#  'BS in Science,',
#  'BS in Secondary Education Foreign Language',
#  'BS in Therapeutic Recreation,',
#  'BS in Tourism and Hospitality Management (STHM),',
#  'BS in Tourism and Hospitality Management,',
#  'BS of Arts in',
#  'BS of Ed',
#  'BS of Education,',
#  'BS of Science,',
#  'BS with Distinction',
#  'BS,',
#  'BS, BA',
#  'BS, BA,',
#  'BS, Civil Engineering',
#  'BS, Cum Laude',
#  'BS, Ed',
#  'BS, MS,',
#  'BS, Minor,',
#  'BS, PharmD,',
#  'BS, Secondary Education/Spanish,',
#  'BS, Sports Management,',
#  'BS, sDPT-PhD,',
#  'BS-,',
#  'BS/BA,',
#  'BS/MS',
#  'BS: Adv,',
#  'BSA',
#  'BSA,',
#  'BSAT',
#  'BSArch',
#  'BSBA',
#  'BSBA,',
#  'BSBA,,',
#  'BSC',
#  'BSCE',
#  'BSCE,',
#  'BSE',
#  'BSE,',
#  'BSED,',
#  'BSEE',
#  'BSEE (Electrical Engineering: Computer Concentration),',
#  'BSEE,',
#  'BSEET',
#  'BSEET,',
#  'BSET',
#  'BSET,',
#  'BSEd',
#  'BSEd,',
#  'BSLA',
#  'BSLA - Bachelor of Science in Landscape Architecture,',
#  'BSLA Landscape Architecture',
#  'BSLA,',
#  'BSME',
#  'BSME Cum Laude',
#  'BSME,',
#  'BSN',
#  'BSN,',
#  'BSPharm,',
#  'BSS,',
#  'BSW',
#  'BSW,',
#  'BSW, MSW',
#  'BSW, MSW,',
#  'BSc',
#  'BSc Biology with Teaching,',
#  'BSc Civil Engineering,',
#  'BSc Pharmacy,',
#  'BSc,',
#  'BSed,',
#  'BSof Chemistry',
#  'BTMM',
#  'BTMM,',
#  'BTMM/ Communications,',
#  'Ba',
#  'Ba,',
#  'Baachelor of Business Administration',
#  'Bac',
#  'Baccalaureate',
#  'Baccalaureate Degree',
#  'Baccalaureate of Arts',
#  'Bacehlors,',
#  'Bach',
#  'Bach A&S',
#  'Bach Music Ed',
#  'Bach of Architecture,',
#  'Bach,',
#  "Bachaelor's",
#  'Bachalors,',
#  'Bacharelado em Administra\xc3\xa7\xc3\xa3o de Empresas,',
#  'Bachellor of Science',
#  'BacheloR of Arts',
#  'Bachelor',
#  'Bachelor (BBA)',
#  'Bachelor (Bsc)',
#  'Bachelor - Business Administration',
#  'Bachelor Arts',
#  'Bachelor Business Adminisration,',
#  'Bachelor Business Administration',
#  'Bachelor Business Administration (BBA),',
#  'Bachelor Business Administration,',
#  'Bachelor Degree',
#  'Bachelor Degree in Business Administration',
#  'Bachelor Degree of Science in Civil Engineering,',
#  'Bachelor Degree,',
#  'Bachelor Of Architecture,',
#  'Bachelor Of Arts',
#  'Bachelor Of Arts,',
#  'Bachelor Of Business Administration',
#  'Bachelor Of Science',
#  'Bachelor Of Science Degree,',
#  'Bachelor Of Science,',
#  'Bachelor Real Estate',
#  'Bachelor Science',
#  'Bachelor Science in Chemistry,',
#  'Bachelor Science of Architecture (BSArch)',
#  'Bachelor and Master Degrees',
#  'Bachelor degree,',
#  'Bachelor in Arts',
#  'Bachelor in Business Administration',
#  'Bachelor in Business Management,',
#  'Bachelor in Business,',
#  'Bachelor in Science,',
#  'Bachelor in the Art of Communication,',
#  'Bachelor of',
#  'Bachelor of Administration',
#  'Bachelor of Administration,',
#  'Bachelor of Applied Science (BASc)',
#  'Bachelor of Applied Science (BASc) Emphasis in Health and PE',
#  'Bachelor of Applied Science (BASc) in Education,',
#  'Bachelor of Applied Science (BASc),',
#  'Bachelor of Applied Science (BSc)',
#  'Bachelor of Applied Sciences',
#  'Bachelor of Architecture',
#  'Bachelor of Architecture (BArch)',
#  'Bachelor of Architecture (BArch),',
#  'Bachelor of Architecture (BSArch),',
#  'Bachelor of Architecture (Incomplete)',
#  'Bachelor of Architecture 5 Year Program',
#  'Bachelor of Architecture,',
#  'Bachelor of Architecture, BS',
#  'Bachelor of Art',
#  'Bachelor of Art Degree,',
#  'Bachelor of Art Social Work,',
#  'Bachelor of Art,',
#  'Bachelor of Arts',
#  'Bachelor of Arts & Sciences,',
#  'Bachelor of Arts (BA',
#  'Bachelor of Arts (BA)',
#  'Bachelor of Arts (BA) (Laurea),',
#  'Bachelor of Arts (BA) (Magna Cum Laude),',
#  'Bachelor of Arts (BA) (licenciatura),',
#  'Bachelor of Arts (BA) - Attempted,',
#  'Bachelor of Arts (BA) - Communications',
#  'Bachelor of Arts (BA) ; Bachelor of Arts (BA),',
#  'Bachelor of Arts (BA) Criminal Justice, Bachelor of Arts (BA) Psychology,',
#  'Bachelor of Arts (BA) English',
#  'Bachelor of Arts (BA) Magna Cum Laude,',
#  'Bachelor of Arts (BA) School of Communications and Theatre,',
#  'Bachelor of Arts (BA) in Communications',
#  'Bachelor of Arts (BA) in Communications,',
#  'Bachelor of Arts (BA) in Mathematics',
#  'Bachelor of Arts (BA) in Media Studies and Communication,',
#  'Bachelor of Arts (BA) with Concentration in the Fine Arts,',
#  'Bachelor of Arts (BA),',
#  'Bachelor of Arts (BA), Bachelor of Science (BS),',
#  'Bachelor of Arts (BA), Communication and Media Studies',
#  'Bachelor of Arts (BA), Concentration in Creative Writing',
#  'Bachelor of Arts (BA), Cum Laude,',
#  'Bachelor of Arts (BA), Dance',
#  'Bachelor of Arts (BA), Minor',
#  'Bachelor of Arts (BA), Political Science',
#  'Bachelor of Arts (BA), Summa Cum Laude',
#  'Bachelor of Arts (BA), Summa Cum Laude,',
#  'Bachelor of Arts (BA), cum laude,',
#  'Bachelor of Arts (BA)--not completed,',
#  'Bachelor of Arts (BA)2,',
#  'Bachelor of Arts (BA); Distinction in Major, Minor in History',
#  'Bachelor of Arts (BA); Magna Cum Laude',
#  'Bachelor of Arts (BA); Minor in Public Health,',
#  'Bachelor of Arts (BFA)',
#  'Bachelor of Arts (BS)',
#  'Bachelor of Arts 1995,',
#  'Bachelor of Arts 2000,',
#  'Bachelor of Arts Communications',
#  'Bachelor of Arts Degree',
#  'Bachelor of Arts Degree,',
#  'Bachelor of Arts Degree; School',
#  'Bachelor of Arts Environmental Studies',
#  'Bachelor of Arts Human Biology/Biological Anthropology,',
#  'Bachelor of Arts and Communications',
#  'Bachelor of Arts and Sciences',
#  'Bachelor of Arts degree,',
#  'Bachelor of Arts degrees,',
#  'Bachelor of Arts in Advertising',
#  'Bachelor of Arts in Advertising,',
#  'Bachelor of Arts in Advertising, 2012',
#  'Bachelor of Arts in Advertising, Business Minor',
#  'Bachelor of Arts in Broadcasting, Telecommunications and Mass Media',
#  'Bachelor of Arts in Business Administration,',
#  'Bachelor of Arts in Business Adminstration',
#  'Bachelor of Arts in Communication',
#  'Bachelor of Arts in Communication,',
#  'Bachelor of Arts in Communications',
#  'Bachelor of Arts in Communications,',
#  'Bachelor of Arts in Elementary & Special Education',
#  'Bachelor of Arts in History',
#  'Bachelor of Arts in Human Resource Management',
#  'Bachelor of Arts in Journalism',
#  'Bachelor of Arts in Liberal Arts,',
#  'Bachelor of Arts in Psychology; Bachelor of Arts in Criminal Justice',
#  'Bachelor of Arts in Sociology, Minor in Business Administration',
#  'Bachelor of Arts in Speech-Language-Hearing,',
#  'Bachelor of Arts in Strategic & Organizational Communication,',
#  'Bachelor of Arts in Strategic Communication',
#  'Bachelor of Arts in Strategic and Organizational Communications',
#  'Bachelor of Arts,',
#  'Bachelor of Arts, BA',
#  'Bachelor of Arts, Bachelor of Fine Arts,',
#  'Bachelor of Arts, Communications,',
#  'Bachelor of Arts, Communications; Public Relations and Advertising,',
#  'Bachelor of Arts, Cum Laude',
#  'Bachelor of Arts, Cum Laude,',
#  'Bachelor of Arts, Magna Cum Laude',
#  'Bachelor of Arts, Magna Cum Laude,',
#  'Bachelor of Arts, School',
#  'Bachelor of Arts, School of Communication and Arts, Media Arts,',
#  'Bachelor of Arts, Social Science,',
#  'Bachelor of Arts, Strategic Communication',
#  'Bachelor of Arts, Summa cum Laude,',
#  'Bachelor of Arts, magna cum laude',
#  'Bachelor of Arts- Advertising and Communications',
#  'Bachelor of Arts/Science',
#  'Bachelor of Arts; BA,',
#  'Bachelor of Arts; Bachelor of Arts,',
#  'Bachelor of Arts; General Business Minor,',
#  'Bachelor of Arts; School',
#  'Bachelor of Arts; School,',
#  'Bachelor of Arts; of',
#  'Bachelor of Arts;January 2012',
#  'Bachelor of Broadcast Telecommunications and Mass Media,',
#  'Bachelor of Busines Administration',
#  'Bachelor of Busines Administration,',
#  'Bachelor of Business',
#  'Bachelor of Business & Administration',
#  'Bachelor of Business A dministration,',
#  'Bachelor of Business Admin',
#  'Bachelor of Business Admin,',
#  'Bachelor of Business Administration',
#  'Bachelor of Business Administration (BA),',
#  'Bachelor of Business Administration (BBA)',
#  'Bachelor of Business Administration (BBA) & Master of Science in Education,',
#  'Bachelor of Business Administration (BBA) - Fox School of Business,',
#  'Bachelor of Business Administration (BBA) @ Fox School of Business',
#  'Bachelor of Business Administration (BBA) Cum Laude',
#  'Bachelor of Business Administration (BBA) Expected',
#  'Bachelor of Business Administration (BBA) FINANCE',
#  'Bachelor of Business Administration (BBA) Honors Program',
#  'Bachelor of Business Administration (BBA) International Business and Marketing',
#  'Bachelor of Business Administration (BBA) and Minor in Management Information Systems',
#  'Bachelor of Business Administration (BBA) cum laude',
#  'Bachelor of Business Administration (BBA) in Finance, MInor in MIS',
#  'Bachelor of Business Administration (BBA) in Sept 2012,',
#  'Bachelor of Business Administration (BBA) | University Honors Program',
#  'Bachelor of Business Administration (BBA),',
#  'Bachelor of Business Administration (BBA), Bachelor of Arts (BA),',
#  'Bachelor of Business Administration (BBA), Master of Science in Human Resource Mgmtt',
#  'Bachelor of Business Administration (BBA), Risk Management and Insurance',
#  'Bachelor of Business Administration (BBA), Risk Management, Cum Laude',
#  'Bachelor of Business Administration (BBA), Summa Cum Laude,',
#  'Bachelor of Business Administration (BBA), magna cum laude',
#  'Bachelor of Business Administration (BBA)- Finance,',
#  'Bachelor of Business Administration (BBA)- Risk Mgt & Ins And Statistics',
#  'Bachelor of Business Administration (BBA)/Bachelor of Arts (BA),',
#  'Bachelor of Business Administration (BBA): Temple University',
#  'Bachelor of Business Administration (BBA); Business Honors Graduate',
#  'Bachelor of Business Administration (BBA-dual degree)',
#  'Bachelor of Business Administration - Marketing',
#  'Bachelor of Business Administration Degree',
#  'Bachelor of Business Administration Degree,',
#  'Bachelor of Business Administration Fox School,',
#  'Bachelor of Business Administration,',
#  'Bachelor of Business Administration, December 2008,',
#  'Bachelor of Business Administration, Dual,',
#  'Bachelor of Business Administration, Graduation: August 2008,',
#  'Bachelor of Business Administration, Graduation: May 2012',
#  'Bachelor of Business Administration, Honors Program',
#  'Bachelor of Business Administration, Major: Marketing, Minor: Management Information Systems at Temp',
#  'Bachelor of Business Administration, Marketing',
#  'Bachelor of Business Administration, awarded magna cum luade,',
#  'Bachelor of Business Administration; Bachelor',
#  'Bachelor of Business Administration; FoxSchool,',
#  'Bachelor of Business Adminstration',
#  'Bachelor of Business Adminstration,',
#  'Bachelor of Business Admistrations,',
#  'Bachelor of Business Management',
#  'Bachelor of Business Management,',
#  'Bachelor of Business and Administration,',
#  'Bachelor of Business,',
#  'Bachelor of Commerce (BCom)',
#  'Bachelor of Communication',
#  'Bachelor of Communications',
#  'Bachelor of Communications & Theater,',
#  'Bachelor of Communications and Theater',
#  'Bachelor of Communications,',
#  'Bachelor of Criminal Justice,',
#  'Bachelor of Education (BEd)',
#  'Bachelor of Education (BEd),',
#  'Bachelor of Education and English,',
#  'Bachelor of Electrical Engineering',
#  'Bachelor of Engineering',
#  'Bachelor of Engineering (BE)',
#  'Bachelor of Engineering (BE),',
#  'Bachelor of Engineering (BEng)',
#  'Bachelor of Engineering (BEng),',
#  'Bachelor of Engineering,',
#  'Bachelor of Facilities Management',
#  'Bachelor of Film and Media Arts',
#  'Bachelor of Film and Media Arts,',
#  'Bachelor of Fine Art,',
#  'Bachelor of Fine Arts',
#  'Bachelor of Fine Arts (BFA)',
#  'Bachelor of Fine Arts (BFA) Minor in Art History',
#  'Bachelor of Fine Arts (BFA),',
#  'Bachelor of Fine Arts (BFA), Minor in Psychology',
#  'Bachelor of Fine Arts (BFA)-Tyler School of Art,',
#  'Bachelor of Fine Arts Degree,',
#  'Bachelor of Fine Arts,',
#  'Bachelor of Fine Arts, Tyler School of Art',
#  'Bachelor of Hotel Tourism',
#  'Bachelor of Journalism',
#  'Bachelor of Journalism,',
#  'Bachelor of Laws (LLB)',
#  'Bachelor of Liberal Arts',
#  'Bachelor of Liberal Arts,',
#  'Bachelor of Libral Arts',
#  'Bachelor of Musc',
#  'Bachelor of Music',
#  'Bachelor of Music (BM),',
#  'Bachelor of Music in Music Education,',
#  'Bachelor of Music,',
#  'Bachelor of Pharmacy (BPharm)',
#  'Bachelor of Pharmacy (BPharm),',
#  'Bachelor of Psychology',
#  'Bachelor of Psychology,',
#  'Bachelor of Sc',
#  'Bachelor of Science',
#  'Bachelor of Science\tSchool,',
#  'Bachelor of Science (BAS)',
#  'Bachelor of Science (BS)',
#  'Bachelor of Science (BS) (Double Major)',
#  'Bachelor of Science (BS) - Graduating May 2014',
#  'Bachelor of Science (BS) Bachelor of Arts (BA),',
#  'Bachelor of Science (BS) GPA 385',
#  'Bachelor of Science (BS) in Education,',
#  'Bachelor of Science (BS) in Kinesiology,',
#  'Bachelor of Science (BS) in Nursing',
#  'Bachelor of Science (BS) of Landscape Architecture',
#  'Bachelor of Science (BS) with Distinction,',
#  'Bachelor of Science (BS),',
#  'Bachelor of Science (BS), Bachelor of Art (BA),',
#  'Bachelor of Science (BS), Cum Laude',
#  'Bachelor of Science (BS), Cum Laude,',
#  'Bachelor of Science (BS), Master of Science (MS),',
#  'Bachelor of Science (BS), Minor in Healthcare Systems Management',
#  'Bachelor of Science (BS), summa cum laude',
#  'Bachelor of Science (BS),,',
#  'Bachelor of Science (BSEd) Elementary Education (K-6), Special Education (K-12)',
#  'Bachelor of Science (BSEd),',
#  'Bachelor of Science (BSc)',
#  'Bachelor of Science (BSc),',
#  'Bachelor of Science / Business Administration',
#  'Bachelor of Science 2009,',
#  'Bachelor of Science Degree',
#  'Bachelor of Science Degree in Tourism and Hospitality Management',
#  'Bachelor of Science Degree,',
#  'Bachelor of Science Ed',
#  'Bachelor of Science Nursing,',
#  'Bachelor of Science and Nursing',
#  'Bachelor of Science and Technology,',
#  'Bachelor of Science degree',
#  'Bachelor of Science degree,',
#  'Bachelor of Science in Architecture',
#  'Bachelor of Science in Architecture,',
#  'Bachelor of Science in Athletic Training (BSAT)',
#  'Bachelor of Science in Athletic Training,',
#  'Bachelor of Science in Biochemistry,',
#  'Bachelor of Science in Business Administration',
#  'Bachelor of Science in Business Administration,',
#  'Bachelor of Science in Business,',
#  'Bachelor of Science in Civil Engineering',
#  'Bachelor of Science in Civil Engineering,',
#  'Bachelor of Science in Civil and Construction Engineering,',
#  'Bachelor of Science in Early Childhood Education,',
#  'Bachelor of Science in Education',
#  'Bachelor of Science in Education & Bachelors of Arts in English',
#  'Bachelor of Science in Education (BSEd)',
#  'Bachelor of Science in Education,',
#  'Bachelor of Science in Electrical Engineering',
#  'Bachelor of Science in Electrical Engineering with Computer',
#  'Bachelor of Science in Engineering',
#  'Bachelor of Science in Engineering (BSE),',
#  'Bachelor of Science in Engineering Technology,',
#  'Bachelor of Science in Exercise and Sport Science',
#  'Bachelor of Science in Finance',
#  'Bachelor of Science in Health Information Management',
#  'Bachelor of Science in Information Science & Technology',
#  'Bachelor of Science in Information Science and Technology',
#  'Bachelor of Science in International Business Studies,',
#  'Bachelor of Science in Kinesiology,',
#  'Bachelor of Science in Landscape Architect',
#  'Bachelor of Science in Landscape Architecture',
#  'Bachelor of Science in Landscape Architecture (BSLA)',
#  'Bachelor of Science in Landscape Architecture,',
#  'Bachelor of Science in Landscape Arctitecture',
#  'Bachelor of Science in Mathematics with Teaching Certificate,',
#  'Bachelor of Science in Mechanical Engineering (BSME), Bachelor of Arts (BA)',
#  'Bachelor of Science in Mechanical Engineering,',
#  'Bachelor of Science in Nursing',
#  'Bachelor of Science in Nursing (BSN)',
#  'Bachelor of Science in Nursing (BSN),',
#  'Bachelor of Science in Nursing,',
#  'Bachelor of Science in Pharmacy,',
#  ...]
